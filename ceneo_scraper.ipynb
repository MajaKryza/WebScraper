# %% [markdown]
# ##Import bibliotek

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# # Pobieranie z serwisu Ceneo.pl opinii o wybranym produkcie
#
#
# *   91869341
# *   83177636
# *   32918774
# *   106545192
# *   124893467

# %% [markdown]
# Wysyłanie żądania dostępu do zasobu (strony WWW)

# %%
headers = {
    "cookie" : "__RequestVerificationToken=0nVdShWL8DeCPQa1sNFao-QS4HpSUDyLVMJtTttShZrVI5MCrPhjglOH2qOd9mx8cStdTL-1HtbsmsdxeDztzLFhJ9KbScm8UDu1fv1MGZs1",
    "User Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/146.0.0.0 Safari/537.36",
    "Host" : "https://www.ceneo.pl"


}

# %%
url = "https://www.ceneo.pl/124893467#tab=reviews"
response = requests.get(url, headers=headers)
print(response.status_code)

# %%
page_dom = BeautifulSoup(response.text, 'html.parser')

# %%
opinions = page_dom.select("div.js_product-review:(.user-post--highlight)")
print(len(opinions))

# %%
opinion = opinions.pop(0)
print(type(opinion))

# %% [markdown]
# ##
